# %% [markdown]
# I/  SVM
# II/ TP M107-79-81

# %%
#importation des bibliotheque
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC, SVR
from sklearn.metrics import confusion_matrix, classification_report

# %%
#chargement de la base de donnees
data=pd.read_csv("bill_authentication.csv")

# %%
#Afficher l'en tete de la DB et sa dimension
print(data.head(),\
      "\nDimension:",data.shape)
# Out:
#    Variance  Skewness  Curtosis  Entropy  Class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0
# Dimension: (1372, 5)

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %%
x_train ,x_test ,y_train ,y_test = train_test_split(x,y,test_size=1.0/3)

# %%
classifier = SVC(kernel = "linear", random_state = 0)
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred=classifier.predict(x_test)

# %%
sb.pairplot(data,hue="Class",palette="Set1")

# %%
#matrice de confusion et visualisation
cm=confusion_matrix(y_test,y_pred)
sb.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
# Rapport de classification
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       249
#            1       0.99      0.99      0.99       209
#
#     accuracy                           0.99       458
#    macro avg       0.99      0.99      0.99       458
# weighted avg       0.99      0.99      0.99       458

# %% [markdown]
# #########################################################################
# TP M107-79-81

# %%
#1 Chargement de bd "IRIS"
irisdata=pd.read_csv("iris.csv")

# %%
#2 l'en tete de base de donnees
irisdata.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
# 3 interpretation des resultat

sb.pairplot(irisdata,hue="variety",palette="Set2")

# %%
# 4
Q=irisdata.iloc[:,:-1].values
Z=irisdata.iloc[:,-1].values
Q_train,Q_test,Z_train,Z_test=train_test_split(Q,Z,test_size=1.0/3)

# %% [markdown]
# #5
# from sklearn.svm import SVC
# from sklearn.metrics import confusion_matrix, classification_report

# %%
# 6
clfr_linear= SVC(kernel="linear",random_state=1)

# %%
clfr_linear.fit(Q_train,Z_train)
# Out:
# SVC(kernel='linear', random_state=1)

# %%
prediction_L=clfr_linear.predict(Q_test)
print(prediction_L)
# Out:
# ['Virginica' 'Virginica' 'Setosa' 'Setosa' 'Virginica' 'Virginica'
#  'Setosa' 'Versicolor' 'Virginica' 'Virginica' 'Versicolor' 'Setosa'
#  'Setosa' 'Setosa' 'Setosa' 'Virginica' 'Virginica' 'Virginica'
#  'Virginica' 'Setosa' 'Virginica' 'Setosa' 'Setosa' 'Versicolor' 'Setosa'
#  'Versicolor' 'Versicolor' 'Versicolor' 'Virginica' 'Versicolor'
#  'Versicolor' 'Virginica' 'Virginica' 'Setosa' 'Virginica' 'Virginica'
#  'Virginica' 'Versicolor' 'Versicolor' 'Setosa' 'Versicolor' 'Setosa'
#  'Setosa' 'Virginica' 'Setosa' 'Versicolor' 'Versicolor' 'Virginica'
#  'Virginica' 'Versicolor']

# %%
# 7 Calcul de precision
clfr_linear.score(Q_test,Z_test)
# Out:
# 1.0

# %%
# 8 Matrice de confusion
conf_matrx=confusion_matrix(Z_test,prediction_L)

# %%
# visualisation dela matrice de confusion
sb.heatmap(conf_matrx,annot=True)
# Out:
# <Axes: >

# %%
#9 Rapport de classification
rc=classification_report(Z_test,prediction_L)
print(rc)
# Out:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        16
#   Versicolor       1.00      1.00      1.00        14
#    Virginica       1.00      1.00      1.00        20
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50

# %%
# 10 - 11
clfr_rbf=SVC(kernel="rbf",gamma=0.001)
clfr_rbf.fit(Q_train,Z_train)
# Out:
# SVC(gamma=0.001)

# %%
prediction_rbf=clfr_rbf.predict(Q_test)

# %%
prediction_rbf
# Out:
# array(['Versicolor', 'Versicolor', 'Versicolor', 'Versicolor',
#        'Versicolor', 'Versicolor', 'Versicolor', 'Versicolor',
#        'Versicolor', 'Versicolor', 'Versicolor', 'Versicolor',
#        'Versicolor', 'Versicolor', 'Versicolor', 'Versicolor',
#        'Versicolor', 'Versicolor', 'Versicolor', 'Versicolor',
#        'Versicolor', 'Versicolor', 'Versicolor', 'Versicolor',
#        'Versicolor', 'Versicolor', 'Versicolor', 'Versicolor',
#        'Versicolor', 'Versicolor', 'Versicolor', 'Versicolor',
#        'Versicolor', 'Versicolor', 'Versicolor', 'Versicolor',
#        'Versicolor', 'Versicolor', 'Versicolor', 'Versicolor',
#        'Versicolor', 'Versicolor', 'Versicolor', 'Versicolor',
#        'Versicolor', 'Versicolor', 'Versicolor', 'Versicolor',
#        'Versicolor', 'Versicolor'], dtype=object)

# %%
clfr_rbf.score(Q_test,Z_test)
# Out:
# 0.28

# %%
#12 Matrice de confusion
conf_matrx2=confusion_matrix(Z_test,prediction_rbf)

#visualisation dela matrice de confusion
sb.heatmap(conf_matrx2,annot=True)
# Out:
# <Axes: >

# %%
#13
print(classification_report(Z_test,prediction_rbf))
# Out:
#               precision    recall  f1-score   support
#
#       Setosa       0.00      0.00      0.00        16
#   Versicolor       0.28      1.00      0.44        14
#    Virginica       0.00      0.00      0.00        20
#
#     accuracy                           0.28        50
#    macro avg       0.09      0.33      0.15        50
# weighted avg       0.08      0.28      0.12        50
# c:\Users\ayach\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
#14

from sklearn import model_selection
C_range = np.logspace(-2, 3, 6)
gamma_range = np.logspace(-2, 1, 4)
param_grid = {'C': C_range, 'gamma': gamma_range}
score = 'accuracy'
grid = model_selection.GridSearchCV(SVC(kernel='rbf'),
param_grid, cv=5)
grid.fit(Q_train, Z_train)
print("Les paramèters optimaux sont {} avec un score de {:.2f}".format(grid.best_params_, grid.best_score_))
# Out:
# Les paramèters optimaux sont {'C': 10.0, 'gamma': 0.1} avec un score de 0.98

# %%
#15

from sklearn import metrics
kmatrix = metrics.pairwise.rbf_kernel(Q_train, gamma=0.1)
plt.pcolor(kmatrix, cmap=plt.cm.PuRd)
plt.colorbar()
plt.gca().invert_yaxis()
plt.gca().xaxis.tick_top()
plt.show()

# %% [markdown]
# SAUVEGARDE DU MODEL

# %%
#16 

import joblib as jl
filename = "iris_model.h5"
jl.dump(grid, filename)
# Out:
# ['iris_model.h5']

# %% [markdown]
# Score du model applique

# %%
loaded_model= jl.load(filename)
result= loaded_model.score(Q_test,Z_test)
print(result)
# Out:
# 0.98

# %% [markdown]
# TEST DU MODEL

# %%
a = input()
b = input()
c = input()
d = input()
test=[[a,b,c,d]]
prediction_test = loaded_model.predict(test)
print(prediction_test)
# Out:
# ['Setosa']
